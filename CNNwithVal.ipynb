# %% [markdown]
# <a href="https://colab.research.google.com/github/deathstar1/Exploration/blob/main/CNNwithVal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip  -O /tmp/horse-or-human.zip
# Out:
# --2020-10-20 14:20:04--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.24.128, 172.217.194.128, 2404:6800:4003:c00::80, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.24.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘/tmp/horse-or-human.zip’
#
# /tmp/horse-or-human 100%[===================>] 142.65M   172MB/s    in 0.8s
#
# 2020-10-20 14:20:05 (172 MB/s) - ‘/tmp/horse-or-human.zip’ saved [149574867/149574867]

# %%
# !wget --no-check-certificate https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip  -O /tmp/validation-horse-or-human.zip
# Out:
# --2020-10-20 14:23:17--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.194.128, 2404:6800:4003:c03::80, 2404:6800:4003:c00::80, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.194.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11480187 (11M) [application/zip]
# Saving to: ‘/tmp/validation-horse-or-human.zip’
#
# /tmp/validation-hor 100%[===================>]  10.95M  17.5MB/s    in 0.6s
#
# 2020-10-20 14:23:18 (17.5 MB/s) - ‘/tmp/validation-horse-or-human.zip’ saved [11480187/11480187]

# %%
import os
import zipfile 
local_zip = '/tmp/horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip ,'r')
zip_ref.extractall('/tmp/horse-or-human')
zip_ref.close()

# %%
import os
import zipfile 
local_zip = '/tmp/validation-horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip ,'r')
zip_ref.extractall('/tmp/validation-horse-or-human')
zip_ref.close()

# %%
training_horses = os.path.join('/tmp/horse-or-human/horses')
training_humans = os.path.join('/tmp/horse-or-human/humans')
val_training_horses = os.path.join('/tmp/validation-horse-or-human/horses')
val_training_humans = os.path.join('/tmp/validation-horse-or-human/humans')

# %%
training_horse_img = os.listdir(training_horses)
print(training_horse_img)
training_human_img = os.listdir(training_humans)
print(training_human_img)
test_human_img = os.listdir(training_humans)
print(test_human_img)
# Out:
# ['horse22-7.png', 'horse16-6.png', 'horse39-9.png', 'horse43-2.png', 'horse19-1.png', 'horse36-6.png', 'horse15-7.png', 'horse27-6.png', 'horse16-3.png', 'horse38-7.png', 'horse13-9.png', 'horse41-5.png', 'horse08-3.png', 'horse16-1.png', 'horse23-1.png', 'horse04-5.png', 'horse31-7.png', 'horse43-6.png', 'horse20-1.png', 'horse16-5.png', 'horse29-9.png', 'horse46-6.png', 'horse29-4.png', 'horse43-9.png', 'horse39-7.png', 'horse09-8.png', 'horse09-7.png', 'horse13-5.png', 'horse40-3.png', 'horse48-9.png', 'horse35-3.png', 'horse08-4.png', 'horse31-9.png', 'horse48-3.png', 'horse24-0.png', 'horse49-6.png', 'horse32-1.png', 'horse37-7.png', 'horse20-7.png', 'horse44-2.png', 'horse35-0.png', 'horse13-0.png', 'horse45-1.png', 'horse06-2.png', 'horse17-5.png', 'horse42-6.png', 'horse01-5.png', 'horse03-6.png', 'horse37-6.png', 'horse24-1.png', 'horse02-2.png', 'horse19-8.png', 'horse09-5.png', 'horse23-0.png', 'horse13-7.png', 'horse26-2.png', 'horse35-1.png', 'horse43-8.png', 'horse01-3.png', 'horse43-5.png', 'horse08-5.png', 'horse45-2.png', 'horse21-0.png', 'horse16-9.png', 'horse02-8.png', 'horse24-5.png', 'horse47-6.png', 'horse09-6.png', 'horse27-2.png', 'horse49-5.png', 'horse43-1.png', 'horse06-9.png', 'horse07-7.png', 'horse19-0.png', 'horse31-1.png', 'horse33-2.png', 'horse02-7.png', 'horse14-0.png', 'horse38-2.png', 'horse04-7.png', 'horse44-6.png', 'horse28-8.png', 'horse30-3.png', 'horse33-1.png', 'horse11-7.png', 'horse17-2.png', 'horse50-7.png', 'horse06-3.png', 'horse50-6.png', 'horse40-0.png', 'horse05-3.png', 'horse11-4.png', 'horse48-8.png', 'horse05-5.png', 'horse23-5.png', 'horse46-7.png', 'horse32-2.png', 'horse08-1.png', 'horse50-5.png', 'horse17-4.png', 'horse07-6.png', 'horse23-4.png', 'horse45-4.png', 'horse43-0.png', 'horse32-3.png', 'horse21-8.png', 'horse25-7.png', 'horse07-0.png', 'horse48-1.png', 'horse39-8.png', 'horse14-7.png', 'horse43-7.png', 'horse37-9.png', 'horse27-0.png', 'horse32-8.png', 'horse40-8.png', 'horse15-3.png', 'horse48-6.png', 'horse46-9.png', 'horse22-1.png', 'horse41-4.png', 'horse03-9.png', 'horse17-8.png', 'horse27-1.png', 'horse45-8.png', 'horse50-8.png', 'horse01-9.png', 'horse06-0.png', 'horse19-6.png', 'horse01-1.png', 'horse21-4.png', 'horse17-6.png', 'horse44-1.png', 'horse30-1.png', 'horse02-5.png', 'horse28-6.png', 'horse19-4.png', 'horse33-0.png', 'horse11-2.png', 'horse10-8.png', 'horse34-0.png', 'horse02-1.png', 'horse24-6.png', 'horse34-8.png', 'horse37-4.png', 'horse50-2.png', 'horse21-9.png', 'horse05-1.png', 'horse19-3.png', 'horse47-2.png', 'horse23-2.png', 'horse33-7.png', 'horse42-8.png', 'horse04-9.png', 'horse47-3.png', 'horse18-4.png', 'horse22-8.png', 'horse02-9.png', 'horse15-0.png', 'horse44-7.png', 'horse32-5.png', 'horse41-3.png', 'horse31-8.png', 'horse34-2.png', 'horse01-4.png', 'horse26-6.png', 'horse36-3.png', 'horse07-9.png', 'horse07-8.png', 'horse10-9.png', 'horse18-8.png', 'horse02-0.png', 'horse40-7.png', 'horse06-7.png', 'horse46-0.png', 'horse10-1.png', 'horse39-6.png', 'horse05-0.png', 'horse09-3.png', 'horse08-8.png', 'horse28-9.png', 'horse37-2.png', 'horse03-5.png', 'horse01-8.png', 'horse01-0.png', 'horse27-7.png', 'horse30-7.png', 'horse19-5.png', 'horse48-7.png', 'horse24-7.png', 'horse28-0.png', 'horse20-9.png', 'horse30-4.png', 'horse21-3.png', 'horse38-0.png', 'horse21-2.png', 'horse14-3.png', 'horse42-4.png', 'horse41-9.png', 'horse40-5.png', 'horse28-1.png', 'horse45-5.png', 'horse05-8.png', 'horse43-3.png', 'horse11-6.png', 'horse49-7.png', 'horse07-2.png', 'horse18-5.png', 'horse39-4.png', 'horse03-0.png', 'horse17-0.png', 'horse11-0.png', 'horse06-1.png', 'horse04-2.png', 'horse16-2.png', 'horse09-0.png', 'horse14-1.png', 'horse12-7.png', 'horse04-4.png', 'horse32-4.png', 'horse22-2.png', 'horse11-8.png', 'horse42-5.png', 'horse48-2.png', 'horse45-9.png', 'horse44-9.png', 'horse08-7.png', 'horse25-1.png', 'horse31-5.png', 'horse49-9.png', 'horse47-8.png', 'horse08-0.png', 'horse15-6.png', 'horse24-2.png', 'horse44-5.png', 'hor ...
# ['human09-09.png', 'human10-07.png', 'human05-05.png', 'human15-30.png', 'human16-03.png', 'human17-23.png', 'human02-09.png', 'human07-07.png', 'human02-27.png', 'human05-29.png', 'human10-14.png', 'human03-04.png', 'human11-25.png', 'human14-07.png', 'human11-29.png', 'human07-09.png', 'human09-02.png', 'human04-09.png', 'human12-28.png', 'human06-24.png', 'human17-01.png', 'human05-23.png', 'human10-10.png', 'human07-01.png', 'human11-07.png', 'human02-07.png', 'human03-30.png', 'human11-14.png', 'human17-29.png', 'human17-28.png', 'human07-21.png', 'human03-08.png', 'human02-24.png', 'human14-11.png', 'human04-05.png', 'human03-24.png', 'human07-11.png', 'human07-22.png', 'human04-20.png', 'human02-11.png', 'human02-20.png', 'human06-22.png', 'human13-00.png', 'human08-20.png', 'human10-04.png', 'human05-22.png', 'human16-06.png', 'human01-04.png', 'human04-24.png', 'human13-08.png', 'human12-19.png', 'human13-15.png', 'human02-03.png', 'human15-07.png', 'human14-09.png', 'human02-05.png', 'human12-20.png', 'human16-17.png', 'human11-01.png', 'human05-01.png', 'human12-01.png', 'human16-19.png', 'human04-14.png', 'human02-10.png', 'human17-20.png', 'human15-16.png', 'human12-30.png', 'human09-12.png', 'human04-27.png', 'human15-22.png', 'human01-29.png', 'human06-01.png', 'human01-26.png', 'human08-16.png', 'human07-16.png', 'human15-28.png', 'human01-07.png', 'human13-17.png', 'human05-19.png', 'human08-01.png', 'human15-29.png', 'human02-08.png', 'human02-06.png', 'human12-09.png', 'human05-04.png', 'human08-26.png', 'human13-04.png', 'human11-09.png', 'human02-19.png', 'human01-23.png', 'human08-08.png', 'human01-08.png', 'human12-13.png', 'human08-15.png', 'human04-04.png', 'human12-14.png', 'human04-02.png', 'human04-01.png', 'human05-03.png', 'human06-14.png', 'human09-29.png', 'human12-29.png', 'human09-01.png', 'human09-00.png', 'human10-29.png', 'human17-06.png', 'human15-20.png', 'human04-21.png', 'human09-05.png', 'human17-00.png', 'human15-18.png', 'human08-03.png', 'human02-21.png', 'human14-25.png', 'human16-01.png', 'human04-11.png', 'human09-26.png', 'human10-26.png', 'human05-15.png', 'human06-13.png', 'human07-03.png', 'human01-05.png', 'human07-15.png', 'human08-21.png', 'human15-27.png', 'human03-18.png', 'human10-17.png', 'human12-17.png', 'human14-04.png', 'human10-01.png', 'human08-17.png', 'human09-17.png', 'human04-10.png', 'human02-14.png', 'human17-13.png', 'human15-24.png', 'human04-23.png', 'human05-30.png', 'human03-11.png', 'human14-15.png', 'human14-28.png', 'human11-06.png', 'human15-23.png', 'human17-11.png', 'human06-11.png', 'human17-08.png', 'human14-29.png', 'human08-23.png', 'human10-11.png', 'human08-12.png', 'human01-10.png', 'human02-17.png', 'human04-08.png', 'human03-20.png', 'human09-16.png', 'human14-27.png', 'human02-23.png', 'human08-11.png', 'human11-04.png', 'human16-30.png', 'human10-28.png', 'human16-02.png', 'human10-05.png', 'human16-14.png', 'human13-22.png', 'human06-16.png', 'human07-29.png', 'human01-22.png', 'human04-30.png', 'human01-18.png', 'human03-26.png', 'human11-26.png', 'human06-05.png', 'human11-10.png', 'human15-06.png', 'human07-02.png', 'human17-18.png', 'human17-27.png', 'human02-18.png', 'human04-28.png', 'human15-04.png', 'human01-09.png', 'human07-26.png', 'human09-25.png', 'human09-08.png', 'human06-20.png', 'human14-24.png', 'human05-28.png', 'human05-12.png', 'human04-15.png', 'human09-15.png', 'human11-11.png', 'human13-30.png', 'human14-20.png', 'human04-26.png', 'human17-03.png', 'human08-10.png', 'human01-28.png', 'human03-28.png', 'human10-08.png', 'human15-00.png', 'human02-25.png', 'human02-30.png', 'human06-27.png', 'human13-13.png', 'human14-06.png', 'human13-01.png', 'human01-03.png', 'human06-30.png', 'human14-13.png', 'human15-13.png', 'human01-06.png', 'human13-05.png', 'human05-02.png', 'human03-21.png', 'human05-00.png', 'human14-02.png', 'human04-07.png', 'human16-20.png', 'human06-12.png', 'human04-13.png', 'human10-25.png', 'hu ...
# ['human09-09.png', 'human10-07.png', 'human05-05.png', 'human15-30.png', 'human16-03.png', 'human17-23.png', 'human02-09.png', 'human07-07.png', 'human02-27.png', 'human05-29.png', 'human10-14.png', 'human03-04.png', 'human11-25.png', 'human14-07.png', 'human11-29.png', 'human07-09.png', 'human09-02.png', 'human04-09.png', 'human12-28.png', 'human06-24.png', 'human17-01.png', 'human05-23.png', 'human10-10.png', 'human07-01.png', 'human11-07.png', 'human02-07.png', 'human03-30.png', 'human11-14.png', 'human17-29.png', 'human17-28.png', 'human07-21.png', 'human03-08.png', 'human02-24.png', 'human14-11.png', 'human04-05.png', 'human03-24.png', 'human07-11.png', 'human07-22.png', 'human04-20.png', 'human02-11.png', 'human02-20.png', 'human06-22.png', 'human13-00.png', 'human08-20.png', 'human10-04.png', 'human05-22.png', 'human16-06.png', 'human01-04.png', 'human04-24.png', 'human13-08.png', 'human12-19.png', 'human13-15.png', 'human02-03.png', 'human15-07.png', 'human14-09.png', 'human02-05.png', 'human12-20.png', 'human16-17.png', 'human11-01.png', 'human05-01.png', 'human12-01.png', 'human16-19.png', 'human04-14.png', 'human02-10.png', 'human17-20.png', 'human15-16.png', 'human12-30.png', 'human09-12.png', 'human04-27.png', 'human15-22.png', 'human01-29.png', 'human06-01.png', 'human01-26.png', 'human08-16.png', 'human07-16.png', 'human15-28.png', 'human01-07.png', 'human13-17.png', 'human05-19.png', 'human08-01.png', 'human15-29.png', 'human02-08.png', 'human02-06.png', 'human12-09.png', 'human05-04.png', 'human08-26.png', 'human13-04.png', 'human11-09.png', 'human02-19.png', 'human01-23.png', 'human08-08.png', 'human01-08.png', 'human12-13.png', 'human08-15.png', 'human04-04.png', 'human12-14.png', 'human04-02.png', 'human04-01.png', 'human05-03.png', 'human06-14.png', 'human09-29.png', 'human12-29.png', 'human09-01.png', 'human09-00.png', 'human10-29.png', 'human17-06.png', 'human15-20.png', 'human04-21.png', 'human09-05.png', 'human17-00.png', 'human15-18.png', 'human08-03.png', 'human02-21.png', 'human14-25.png', 'human16-01.png', 'human04-11.png', 'human09-26.png', 'human10-26.png', 'human05-15.png', 'human06-13.png', 'human07-03.png', 'human01-05.png', 'human07-15.png', 'human08-21.png', 'human15-27.png', 'human03-18.png', 'human10-17.png', 'human12-17.png', 'human14-04.png', 'human10-01.png', 'human08-17.png', 'human09-17.png', 'human04-10.png', 'human02-14.png', 'human17-13.png', 'human15-24.png', 'human04-23.png', 'human05-30.png', 'human03-11.png', 'human14-15.png', 'human14-28.png', 'human11-06.png', 'human15-23.png', 'human17-11.png', 'human06-11.png', 'human17-08.png', 'human14-29.png', 'human08-23.png', 'human10-11.png', 'human08-12.png', 'human01-10.png', 'human02-17.png', 'human04-08.png', 'human03-20.png', 'human09-16.png', 'human14-27.png', 'human02-23.png', 'human08-11.png', 'human11-04.png', 'human16-30.png', 'human10-28.png', 'human16-02.png', 'human10-05.png', 'human16-14.png', 'human13-22.png', 'human06-16.png', 'human07-29.png', 'human01-22.png', 'human04-30.png', 'human01-18.png', 'human03-26.png', 'human11-26.png', 'human06-05.png', 'human11-10.png', 'human15-06.png', 'human07-02.png', 'human17-18.png', 'human17-27.png', 'human02-18.png', 'human04-28.png', 'human15-04.png', 'human01-09.png', 'human07-26.png', 'human09-25.png', 'human09-08.png', 'human06-20.png', 'human14-24.png', 'human05-28.png', 'human05-12.png', 'human04-15.png', 'human09-15.png', 'human11-11.png', 'human13-30.png', 'human14-20.png', 'human04-26.png', 'human17-03.png', 'human08-10.png', 'human01-28.png', 'human03-28.png', 'human10-08.png', 'human15-00.png', 'human02-25.png', 'human02-30.png', 'human06-27.png', 'human13-13.png', 'human14-06.png', 'human13-01.png', 'human01-03.png', 'human06-30.png', 'human14-13.png', 'human15-13.png', 'human01-06.png', 'human13-05.png', 'human05-02.png', 'human03-21.png', 'human05-00.png', 'human14-02.png', 'human04-07.png', 'human16-20.png', 'human06-12.png', 'human04-13.png', 'human10-25.png', 'hu ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mimg

nrows = 4 
ncols = 4 

pix = 0

pix += 8
next_horse_pic = [os.path.join(training_horses,fname) for fname in  training_horse_img[pix -8 :pix ] ]
next_house_pic = [os.path.join(training_humans,fname) for fname in  training_human_img[pix-8 : pix ] ]
print(next_horse_pic)
# Out:
# ['/tmp/horse-or-human/horses/horse22-7.png', '/tmp/horse-or-human/horses/horse16-6.png', '/tmp/horse-or-human/horses/horse39-9.png', '/tmp/horse-or-human/horses/horse43-2.png', '/tmp/horse-or-human/horses/horse19-1.png', '/tmp/horse-or-human/horses/horse36-6.png', '/tmp/horse-or-human/horses/horse15-7.png', '/tmp/horse-or-human/horses/horse27-6.png']

# %%
fig = plt.gcf()
fig.set_size_inches(ncols * 4 , nrows *4)
for i , img_path in  enumerate(next_horse_pic+ next_house_pic):
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)
  img = mimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32 , (3,3) , activation='relu' , input_shape =(300,300,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64 , (3,3) , activation='relu' ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64 , (3,3) , activation='relu' ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128 , (3,3) , activation='relu' ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128 , (3,3) , activation='relu' ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512 , activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 298, 298, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 147, 147, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 73, 73, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 71, 71, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 33, 33, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,490,049
# Trainable params: 3,490,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001) , loss='binary_crossentropy' , metrics =['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen =  ImageDataGenerator(rescale=1/255)

train_data =  train_gen.flow_from_directory('/tmp/horse-or-human', target_size=(300,300) , batch_size=128 ,  class_mode='binary')

test_gen =  ImageDataGenerator(rescale=1/255)
test_data =  test_gen.flow_from_directory('/tmp/validation-horse-or-human', target_size=(300,300) , batch_size=32 ,  class_mode='binary')
# Out:
# Found 1027 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.

# %%
model.fit_generator(train_data ,steps_per_epoch=8,epochs=15, verbose=1, validation_data=test_data , validation_steps=8)
# Out:
# Epoch 1/15
# 8/8 [==============================] - 8s 999ms/step - loss: 0.0407 - accuracy: 0.9863 - val_loss: 2.2779 - val_accuracy: 0.8242
# Epoch 2/15
# 8/8 [==============================] - 7s 890ms/step - loss: 0.2765 - accuracy: 0.9344 - val_loss: 1.1788 - val_accuracy: 0.8672
# Epoch 3/15
# 8/8 [==============================] - 7s 883ms/step - loss: 0.0690 - accuracy: 0.9744 - val_loss: 1.4687 - val_accuracy: 0.8672
# Epoch 4/15
# 8/8 [==============================] - 7s 871ms/step - loss: 0.0271 - accuracy: 0.9900 - val_loss: 1.7992 - val_accuracy: 0.8672
# Epoch 5/15
# 8/8 [==============================] - 7s 875ms/step - loss: 0.2709 - accuracy: 0.9366 - val_loss: 1.2752 - val_accuracy: 0.8477
# Epoch 6/15
# 8/8 [==============================] - 7s 881ms/step - loss: 0.2267 - accuracy: 0.9477 - val_loss: 1.5550 - val_accuracy: 0.8359
# Epoch 7/15
# 8/8 [==============================] - 7s 879ms/step - loss: 0.0246 - accuracy: 0.9933 - val_loss: 2.0672 - val_accuracy: 0.8477
# Epoch 8/15
# 8/8 [==============================] - 7s 875ms/step - loss: 0.0155 - accuracy: 0.9944 - val_loss: 2.0951 - val_accuracy: 0.8633
# Epoch 9/15
# 8/8 [==============================] - 7s 881ms/step - loss: 2.0947 - accuracy: 0.8743 - val_loss: 2.7652 - val_accuracy: 0.7461
# Epoch 10/15
# 8/8 [==============================] - 7s 880ms/step - loss: 0.0670 - accuracy: 0.9744 - val_loss: 1.6126 - val_accuracy: 0.8555
# Epoch 11/15
# 8/8 [==============================] - 7s 887ms/step - loss: 0.1672 - accuracy: 0.9477 - val_loss: 1.9611 - val_accuracy: 0.8594
# Epoch 12/15
# 8/8 [==============================] - 7s 876ms/step - loss: 0.0112 - accuracy: 0.9978 - val_loss: 1.7383 - val_accuracy: 0.8516
# Epoch 13/15
# 8/8 [==============================] - 7s 887ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.9639 - val_accuracy: 0.8594
# Epoch 14/15
# 8/8 [==============================] - 7s 880ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.1676 - val_accuracy: 0.8555
# Epoch 15/15
# 8/8 [==============================] - 7s 922ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.4156 - val_accuracy: 0.8555

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(300, 300))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " is a human")
  else:
    print(fn + " is a horse")
# Out:
#      <input type="file" id="files-96e99754-679c-4a9c-ab2b-755cde76324c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96e99754-679c-4a9c-ab2b-755cde76324c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.jpg to 2.jpg
# [0.]
# 2.jpg is a horse

# %%
from tensorflow.keras.models  import Model
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img
successive_outputs =  [layer.output  for layer in  model.layers[1:]]
print (successive_outputs)

visualization_model =  Model(inputs = model.input , outputs = successive_outputs)

horse_file = [os.path.join(training_horses, f)  for f in  training_horse_img ]
human_file = [os.path.join(training_humans, f)  for f in  training_human_img ]

# random_select = random.choice(horse_file+human_file)
random_select = human_file[2]
img = load_img(random_select , target_size=(300,300))
x=  img_to_array(img)
x = x.reshape((1,) + x.shape)
x /= 255

successive_feature_maps=  visualization_model.predict(x)
layer_names = [layer.name for layer in model.layers[1:]]
print("here")
for layer_name , successive_feature_map  in zip(layer_names ,  successive_feature_maps):
  if len(successive_feature_map.shape) == 4 :
    n_features = successive_feature_map.shape[-1]
    # The feature map has shape (1, size, size, n_features)
    size = successive_feature_map.shape[1]
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    for i in range(n_features):
      # Postprocess the feature to make it visually palatable
      x = successive_feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
      # We'll tile each filter into this big horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
    # Display the grid
    scale = 20. / n_features
    plt.figure(figsize=(scale * n_features, scale))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# [<tf.Tensor 'max_pooling2d/MaxPool:0' shape=(None, 149, 149, 32) dtype=float32>, <tf.Tensor 'conv2d_1/Relu:0' shape=(None, 147, 147, 64) dtype=float32>, <tf.Tensor 'max_pooling2d_1/MaxPool:0' shape=(None, 73, 73, 64) dtype=float32>, <tf.Tensor 'conv2d_2/Relu:0' shape=(None, 71, 71, 64) dtype=float32>, <tf.Tensor 'max_pooling2d_2/MaxPool:0' shape=(None, 35, 35, 64) dtype=float32>, <tf.Tensor 'conv2d_3/Relu:0' shape=(None, 33, 33, 128) dtype=float32>, <tf.Tensor 'max_pooling2d_3/MaxPool:0' shape=(None, 16, 16, 128) dtype=float32>, <tf.Tensor 'conv2d_4/Relu:0' shape=(None, 14, 14, 128) dtype=float32>, <tf.Tensor 'max_pooling2d_4/MaxPool:0' shape=(None, 7, 7, 128) dtype=float32>, <tf.Tensor 'flatten/Reshape:0' shape=(None, 6272) dtype=float32>, <tf.Tensor 'dense/Relu:0' shape=(None, 512) dtype=float32>, <tf.Tensor 'dense_1/Sigmoid:0' shape=(None, 1) dtype=float32>]
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2f0618f2f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# here
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide

# %%
import os, signal
os.kill(os.getpid(), signal.SIGKILL)

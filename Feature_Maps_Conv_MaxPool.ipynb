# %% [markdown]
# <a href="https://colab.research.google.com/github/deathstar1/Exploration/blob/main/Feature_Maps_Conv_MaxPool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip  -O /tmp/horse-or-human.zip
# Out:
# --2020-10-17 18:34:36--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.20.128, 172.253.117.128, 142.250.99.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.20.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘/tmp/horse-or-human.zip’
#
# /tmp/horse-or-human 100%[===================>] 142.65M  71.9MB/s    in 2.0s
#
# 2020-10-17 18:34:38 (71.9 MB/s) - ‘/tmp/horse-or-human.zip’ saved [149574867/149574867]

# %%
import os
import zipfile 
local_zip = '/tmp/horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip ,'r')
zip_ref.extractall('/tmp/horse-or-human')
zip_ref.close()

# %%
training_horses = os.path.join('/tmp/horse-or-human/horses')
training_humans = os.path.join('/tmp/horse-or-human/humans')

# %%
training_horse_img = os.listdir(training_horses)
print(training_horse_img)
training_human_img = os.listdir(training_humans)
print(training_human_img)
# Out:
# ['horse06-3.png', 'horse12-4.png', 'horse40-6.png', 'horse09-7.png', 'horse36-6.png', 'horse20-5.png', 'horse50-8.png', 'horse16-4.png', 'horse34-9.png', 'horse06-0.png', 'horse43-3.png', 'horse42-8.png', 'horse25-0.png', 'horse14-0.png', 'horse26-8.png', 'horse24-7.png', 'horse47-2.png', 'horse31-9.png', 'horse04-1.png', 'horse05-6.png', 'horse11-1.png', 'horse07-7.png', 'horse31-0.png', 'horse16-3.png', 'horse49-9.png', 'horse45-5.png', 'horse16-2.png', 'horse24-5.png', 'horse21-2.png', 'horse01-9.png', 'horse31-8.png', 'horse19-5.png', 'horse28-8.png', 'horse49-3.png', 'horse36-9.png', 'horse39-7.png', 'horse35-6.png', 'horse30-0.png', 'horse17-8.png', 'horse17-0.png', 'horse16-8.png', 'horse08-0.png', 'horse08-8.png', 'horse32-5.png', 'horse29-4.png', 'horse32-0.png', 'horse04-2.png', 'horse23-9.png', 'horse42-6.png', 'horse02-5.png', 'horse05-2.png', 'horse09-8.png', 'horse10-9.png', 'horse16-7.png', 'horse06-7.png', 'horse09-1.png', 'horse13-2.png', 'horse33-4.png', 'horse30-1.png', 'horse28-9.png', 'horse22-3.png', 'horse31-1.png', 'horse19-6.png', 'horse17-5.png', 'horse01-8.png', 'horse14-4.png', 'horse24-6.png', 'horse13-0.png', 'horse49-0.png', 'horse47-4.png', 'horse10-3.png', 'horse27-4.png', 'horse37-4.png', 'horse15-3.png', 'horse39-4.png', 'horse37-9.png', 'horse11-5.png', 'horse46-2.png', 'horse28-0.png', 'horse04-4.png', 'horse03-5.png', 'horse48-9.png', 'horse01-2.png', 'horse28-4.png', 'horse41-6.png', 'horse48-2.png', 'horse21-0.png', 'horse44-2.png', 'horse44-4.png', 'horse34-4.png', 'horse37-2.png', 'horse10-7.png', 'horse01-7.png', 'horse07-8.png', 'horse14-5.png', 'horse30-9.png', 'horse18-1.png', 'horse17-9.png', 'horse33-3.png', 'horse07-3.png', 'horse28-6.png', 'horse30-4.png', 'horse46-3.png', 'horse18-2.png', 'horse23-8.png', 'horse18-7.png', 'horse15-2.png', 'horse47-0.png', 'horse07-1.png', 'horse41-1.png', 'horse39-9.png', 'horse42-9.png', 'horse37-7.png', 'horse12-3.png', 'horse48-5.png', 'horse45-2.png', 'horse20-9.png', 'horse38-7.png', 'horse42-1.png', 'horse14-2.png', 'horse48-1.png', 'horse43-9.png', 'horse50-4.png', 'horse47-3.png', 'horse36-4.png', 'horse40-1.png', 'horse46-8.png', 'horse05-4.png', 'horse29-8.png', 'horse22-4.png', 'horse46-0.png', 'horse46-6.png', 'horse15-1.png', 'horse21-8.png', 'horse32-8.png', 'horse39-5.png', 'horse33-7.png', 'horse22-1.png', 'horse38-1.png', 'horse24-2.png', 'horse27-0.png', 'horse35-7.png', 'horse05-3.png', 'horse32-7.png', 'horse10-0.png', 'horse35-8.png', 'horse08-5.png', 'horse15-0.png', 'horse08-7.png', 'horse09-0.png', 'horse25-1.png', 'horse20-2.png', 'horse44-3.png', 'horse39-3.png', 'horse45-9.png', 'horse02-6.png', 'horse25-4.png', 'horse27-6.png', 'horse39-2.png', 'horse13-1.png', 'horse29-9.png', 'horse40-8.png', 'horse24-4.png', 'horse29-2.png', 'horse20-7.png', 'horse16-9.png', 'horse07-4.png', 'horse08-6.png', 'horse02-4.png', 'horse43-1.png', 'horse30-3.png', 'horse13-6.png', 'horse49-7.png', 'horse33-6.png', 'horse02-1.png', 'horse39-6.png', 'horse26-9.png', 'horse21-3.png', 'horse46-1.png', 'horse50-9.png', 'horse26-4.png', 'horse32-2.png', 'horse35-2.png', 'horse34-0.png', 'horse12-1.png', 'horse04-9.png', 'horse11-7.png', 'horse47-9.png', 'horse22-6.png', 'horse01-5.png', 'horse19-4.png', 'horse07-2.png', 'horse36-5.png', 'horse42-0.png', 'horse25-3.png', 'horse12-2.png', 'horse31-5.png', 'horse38-4.png', 'horse18-3.png', 'horse03-0.png', 'horse08-4.png', 'horse10-1.png', 'horse43-5.png', 'horse17-2.png', 'horse47-8.png', 'horse13-3.png', 'horse28-7.png', 'horse34-3.png', 'horse46-9.png', 'horse41-5.png', 'horse33-0.png', 'horse11-6.png', 'horse20-0.png', 'horse39-0.png', 'horse05-0.png', 'horse18-4.png', 'horse41-9.png', 'horse45-1.png', 'horse36-8.png', 'horse07-5.png', 'horse05-9.png', 'horse21-7.png', 'horse27-2.png', 'horse17-3.png', 'horse22-5.png', 'horse19-0.png', 'horse19-8.png', 'horse31-6.png', 'horse12-7.png', 'horse31-3.png', 'horse50-5.png', 'horse12-9.png', 'horse45-3.png', 'horse25-9.png', 'horse36-3.png', 'hor ...
# ['human06-23.png', 'human17-04.png', 'human04-15.png', 'human13-02.png', 'human14-15.png', 'human01-20.png', 'human16-29.png', 'human01-07.png', 'human12-28.png', 'human13-09.png', 'human09-09.png', 'human05-25.png', 'human10-05.png', 'human02-14.png', 'human02-00.png', 'human05-03.png', 'human02-07.png', 'human04-13.png', 'human12-14.png', 'human01-02.png', 'human12-24.png', 'human11-11.png', 'human10-07.png', 'human07-28.png', 'human10-30.png', 'human05-02.png', 'human06-16.png', 'human12-05.png', 'human05-17.png', 'human08-29.png', 'human03-23.png', 'human08-12.png', 'human16-23.png', 'human03-00.png', 'human02-13.png', 'human07-22.png', 'human11-23.png', 'human17-07.png', 'human05-29.png', 'human03-28.png', 'human01-25.png', 'human17-17.png', 'human08-08.png', 'human06-06.png', 'human16-26.png', 'human10-19.png', 'human11-13.png', 'human07-02.png', 'human10-27.png', 'human16-16.png', 'human10-11.png', 'human11-12.png', 'human11-05.png', 'human09-24.png', 'human01-15.png', 'human01-00.png', 'human14-21.png', 'human11-15.png', 'human06-11.png', 'human11-27.png', 'human03-13.png', 'human04-11.png', 'human14-25.png', 'human08-13.png', 'human16-14.png', 'human11-04.png', 'human17-08.png', 'human15-29.png', 'human16-00.png', 'human12-26.png', 'human10-03.png', 'human10-28.png', 'human03-06.png', 'human08-21.png', 'human06-27.png', 'human10-23.png', 'human02-22.png', 'human13-05.png', 'human03-07.png', 'human04-14.png', 'human16-25.png', 'human09-19.png', 'human13-03.png', 'human04-00.png', 'human13-17.png', 'human12-10.png', 'human10-02.png', 'human13-21.png', 'human07-03.png', 'human17-19.png', 'human11-09.png', 'human02-08.png', 'human02-11.png', 'human08-23.png', 'human03-11.png', 'human03-04.png', 'human02-27.png', 'human17-13.png', 'human05-06.png', 'human12-30.png', 'human14-03.png', 'human17-25.png', 'human14-23.png', 'human01-18.png', 'human15-02.png', 'human02-25.png', 'human16-19.png', 'human15-20.png', 'human13-06.png', 'human12-07.png', 'human07-25.png', 'human14-07.png', 'human16-01.png', 'human09-26.png', 'human16-09.png', 'human09-15.png', 'human13-25.png', 'human10-29.png', 'human06-18.png', 'human08-15.png', 'human06-30.png', 'human06-01.png', 'human14-24.png', 'human16-30.png', 'human14-08.png', 'human03-10.png', 'human14-17.png', 'human02-19.png', 'human11-14.png', 'human09-08.png', 'human11-24.png', 'human07-20.png', 'human15-25.png', 'human14-01.png', 'human04-01.png', 'human05-04.png', 'human14-20.png', 'human15-08.png', 'human15-26.png', 'human07-11.png', 'human10-21.png', 'human12-18.png', 'human12-08.png', 'human03-19.png', 'human12-23.png', 'human16-04.png', 'human17-11.png', 'human14-30.png', 'human12-17.png', 'human12-25.png', 'human16-20.png', 'human15-16.png', 'human04-21.png', 'human07-07.png', 'human01-23.png', 'human08-00.png', 'human13-04.png', 'human07-18.png', 'human03-25.png', 'human14-00.png', 'human02-23.png', 'human09-27.png', 'human04-22.png', 'human06-00.png', 'human15-14.png', 'human07-27.png', 'human03-16.png', 'human06-03.png', 'human16-12.png', 'human04-12.png', 'human16-08.png', 'human05-18.png', 'human12-06.png', 'human05-21.png', 'human04-06.png', 'human09-22.png', 'human17-18.png', 'human04-27.png', 'human01-01.png', 'human10-00.png', 'human13-26.png', 'human02-29.png', 'human07-14.png', 'human09-05.png', 'human16-28.png', 'human16-11.png', 'human08-05.png', 'human16-07.png', 'human02-12.png', 'human02-05.png', 'human10-16.png', 'human11-17.png', 'human11-29.png', 'human02-01.png', 'human05-14.png', 'human05-07.png', 'human14-06.png', 'human01-22.png', 'human17-01.png', 'human04-10.png', 'human13-18.png', 'human16-05.png', 'human02-28.png', 'human08-16.png', 'human07-17.png', 'human15-10.png', 'human09-04.png', 'human08-04.png', 'human09-25.png', 'human11-19.png', 'human01-28.png', 'human08-30.png', 'human07-12.png', 'human09-07.png', 'human12-12.png', 'human13-23.png', 'human01-29.png', 'human11-07.png', 'human04-07.png', 'human14-18.png', 'human09-12.png', 'human15-23.png', 'hu ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mimg

nrows = 4 
ncols = 4 

pix = 0

pix += 8
next_horse_pic = [os.path.join(training_horses,fname) for fname in  training_horse_img[pix -8 :pix ] ]
next_house_pic = [os.path.join(training_humans,fname) for fname in  training_human_img[pix-8 : pix ] ]
print(next_horse_pic)
# Out:
# ['/tmp/horse-or-human/horses/horse06-3.png', '/tmp/horse-or-human/horses/horse12-4.png', '/tmp/horse-or-human/horses/horse40-6.png', '/tmp/horse-or-human/horses/horse09-7.png', '/tmp/horse-or-human/horses/horse36-6.png', '/tmp/horse-or-human/horses/horse20-5.png', '/tmp/horse-or-human/horses/horse50-8.png', '/tmp/horse-or-human/horses/horse16-4.png']

# %%
fig = plt.gcf()
fig.set_size_inches(ncols * 4 , nrows *4)
for i , img_path in  enumerate(next_horse_pic+ next_house_pic):
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)
  img = mimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32 , (3,3) , activation='relu' , input_shape =(300,300,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64 , (3,3) , activation='relu' ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64 , (3,3) , activation='relu' ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128 , (3,3) , activation='relu' ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128 , (3,3) , activation='relu' ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512 , activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 298, 298, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 147, 147, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 73, 73, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 71, 71, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 33, 33, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,490,049
# Trainable params: 3,490,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001) , loss='binary_crossentropy' , metrics =['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen =  ImageDataGenerator(rescale=1/255)

train_data =  train_gen.flow_from_directory('/tmp/horse-or-human', target_size=(300,300) , batch_size=128 ,  class_mode='binary')
# Out:
# Found 1027 images belonging to 2 classes.

# %%
model.fit_generator(train_data ,steps_per_epoch=8,epochs=15, verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-13-600be5b972bb>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/15
# 2/8 [======>.......................] - ETA: 0s - loss: 0.8971 - accuracy: 0.4766WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0885s vs `on_train_batch_end` time: 0.1880s). Check your callbacks.
# 8/8 [==============================] - 5s 593ms/step - loss: 0.9261 - accuracy: 0.5584
# Epoch 2/15
# 8/8 [==============================] - 5s 660ms/step - loss: 0.9231 - accuracy: 0.6563
# Epoch 3/15
# 8/8 [==============================] - 5s 674ms/step - loss: 0.6701 - accuracy: 0.6363
# Epoch 4/15
# 8/8 [==============================] - 5s 660ms/step - loss: 1.3867 - accuracy: 0.7208
# Epoch 5/15
# 8/8 [==============================] - 5s 664ms/step - loss: 1.2941 - accuracy: 0.6018
# Epoch 6/15
# 8/8 [==============================] - 5s 671ms/step - loss: 0.7030 - accuracy: 0.7786
# Epoch 7/15
# 8/8 [==============================] - 5s 674ms/step - loss: 0.3275 - accuracy: 0.9232
# Epoch 8/15
# 8/8 [==============================] - 5s 671ms/step - loss: 0.2512 - accuracy: 0.9021
# Epoch 9/15
# 8/8 [==============================] - 5s 674ms/step - loss: 0.1192 - accuracy: 0.9488
# Epoch 10/15
# 8/8 [==============================] - 6s 749ms/step - loss: 0.5964 - accuracy: 0.8487
# Epoch 11/15
# 8/8 [==============================] - 5s 672ms/step - loss: 0.1987 - accuracy: 0.9277
# Epoch 12/15
# 8/8 [==============================] - 5s 666ms/step - loss: 0.3819 - accuracy: 0.8621
# Epoch 13/15
# 8/8 [==============================] - 5s 672ms/step - loss: 0.1120 - accuracy: 0.9644
# Epoch 14/15
# 8/8 [==============================] - 5s 683ms/step - loss: 0.0566 - accuracy: 0.9800
# Epoch 15/15
# 8/8 [==============================] - 5s 675ms/step - loss: 0.2343 - accuracy: 0.9366

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(300, 300))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " is a human")
  else:
    print(fn + " is a horse")
# Out:
#      <input type="file" id="files-87f0928b-d01a-4dfc-ae3e-e74beaf34381" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87f0928b-d01a-4dfc-ae3e-e74beaf34381">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.jpg to 2.jpg
# [0.]
# 2.jpg is a horse

# %%
from tensorflow.keras.models  import Model
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img
successive_outputs =  [layer.output  for layer in  model.layers[1:]]
print (successive_outputs)

visualization_model =  Model(inputs = model.input , outputs = successive_outputs)

horse_file = [os.path.join(training_horses, f)  for f in  training_horse_img ]
human_file = [os.path.join(training_humans, f)  for f in  training_human_img ]

# random_select = random.choice(horse_file+human_file)
random_select = human_file[2]
img = load_img(random_select , target_size=(300,300))
x=  img_to_array(img)
x = x.reshape((1,) + x.shape)
x /= 255

successive_feature_maps=  visualization_model.predict(x)
layer_names = [layer.name for layer in model.layers[1:]]
print("here")
for layer_name , successive_feature_map  in zip(layer_names ,  successive_feature_maps):
  if len(successive_feature_map.shape) == 4 :
    n_features = successive_feature_map.shape[-1]
    # The feature map has shape (1, size, size, n_features)
    size = successive_feature_map.shape[1]
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    for i in range(n_features):
      # Postprocess the feature to make it visually palatable
      x = successive_feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
      # We'll tile each filter into this big horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
    # Display the grid
    scale = 20. / n_features
    plt.figure(figsize=(scale * n_features, scale))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# [<tf.Tensor 'max_pooling2d/MaxPool:0' shape=(None, 149, 149, 32) dtype=float32>, <tf.Tensor 'conv2d_1/Relu:0' shape=(None, 147, 147, 64) dtype=float32>, <tf.Tensor 'max_pooling2d_1/MaxPool:0' shape=(None, 73, 73, 64) dtype=float32>, <tf.Tensor 'conv2d_2/Relu:0' shape=(None, 71, 71, 64) dtype=float32>, <tf.Tensor 'max_pooling2d_2/MaxPool:0' shape=(None, 35, 35, 64) dtype=float32>, <tf.Tensor 'conv2d_3/Relu:0' shape=(None, 33, 33, 128) dtype=float32>, <tf.Tensor 'max_pooling2d_3/MaxPool:0' shape=(None, 16, 16, 128) dtype=float32>, <tf.Tensor 'conv2d_4/Relu:0' shape=(None, 14, 14, 128) dtype=float32>, <tf.Tensor 'max_pooling2d_4/MaxPool:0' shape=(None, 7, 7, 128) dtype=float32>, <tf.Tensor 'flatten/Reshape:0' shape=(None, 6272) dtype=float32>, <tf.Tensor 'dense/Relu:0' shape=(None, 512) dtype=float32>, <tf.Tensor 'dense_1/Sigmoid:0' shape=(None, 1) dtype=float32>]
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2f0618f2f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# here
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide

# %%
import os, signal
os.kill(os.getpid(), signal.SIGKILL)

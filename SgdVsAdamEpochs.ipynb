# %% [markdown]
# <a href="https://colab.research.google.com/github/deathstar1/Exploration/blob/main/SgdVsAdamEpochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf 
import numpy as np
from tensorflow import keras

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

x = np.array ([-1 , 1, 2, 3 ,6 ,7] , dtype=int)
y = np.array ([-3 , 1 ,3, 5, 11,13], dtype=int)

# %%
model.fit(x, y , epochs = 2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 48.0714
# Epoch 2/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 48.0058
# Epoch 3/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 47.9404
# Epoch 4/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 47.8749
# Epoch 5/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 47.8095
# Epoch 6/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 47.7442
# Epoch 7/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 47.6789
# Epoch 8/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 47.6137
# Epoch 9/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 47.5485
# Epoch 10/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 47.4834
# Epoch 11/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 47.4183
# Epoch 12/2000
# ...

# %%
print(model.predict([15]))
# Out:
# [[22.47382]]

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')
x = np.array ([-1 , 1, 2, 3 ,6 ,7] , dtype=int)
y = np.array ([-3 , 1 ,3, 5, 11,13], dtype=int)

model.fit(x, y , epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5068
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0750
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8717
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7670
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7049
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6615
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6263
# Epoch 8/500
# 1/1 [==============================] - 0s 974us/step - loss: 1.5951
# Epoch 9/500
# 1/1 [==============================] - 0s 866us/step - loss: 1.5658
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5375
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5101
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4832
# ...

# %%
print(model.predict([15]))
# Out:
# [[28.95985]]
